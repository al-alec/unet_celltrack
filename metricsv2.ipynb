# %%
import matplotlib.pyplot as plt
import ioumatch

image_path = "data/phc/images/"
gt_path = "data/phc/masks/"
predictions_path = "data/phc/pred/"

# %%
impred_path = "data/phc/pred/masks/01_t000_pred.png"
import numpy as np


res = ioumatch.evaluate_paths("data/phc/pred/binary/01_t007.png",
                              "phc/test_dataset/masks/01_t007.tif",
                              threshold=0.3)


for i in np.arange(0.0, 1.0, 0.1):
    res = ioumatch.evaluate_paths("data/phc/pred/binary/01_t007.png",
                              "phc/test_dataset/masks/01_t007.tif",
                              threshold=i)

# %%
res
# Out:
# {'tp': 68,
#  'fp': 9,
#  'fn': 3,
#  'f1': 0.918918918918919,
#  'iou_matrix': array([[0.        , 0.        , 0.        , ..., 0.        , 0.        ,
#          0.        ],
#         [0.88826816, 0.        , 0.        , ..., 0.        , 0.        ,
#          0.        ],
#         [0.        , 0.89162562, 0.        , ..., 0.        , 0.        ,
#          0.        ],
#         ...,
#         [0.        , 0.        , 0.        , ..., 0.85561497, 0.        ,
#          0.        ],
#         [0.        , 0.        , 0.        , ..., 0.        , 0.89810427,
#          0.        ],
#         [0.        , 0.        , 0.        , ..., 0.        , 0.        ,
#          0.80769231]], shape=(77, 71))}
